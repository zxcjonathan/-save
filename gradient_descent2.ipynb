# %% [markdown]
# <a href="https://colab.research.google.com/github/zxc83118/-save/blob/main/gradient_descent2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/GrandmaCan/ML/main/Resgression/Salary_Data.csv"

data = pd.read_csv(url)
data
# y = w*x + b
x = data["YearsExperience"]
y = data["Salary"]

# %%
w = 20
b = 20
#n = len(x)
#w_gradient = (2*x*(w*x+b -y)) .sum() /n #cost function對w作微分的結果，再把其作加總，除以總資料數 w_gradient = (2*x*(w*x+b -y)).mean()
w_gradient = (2*x*(w*x+b -y)).mean()
#b_gradient = (2*(w*x+b -y)) .sum() /n #cost function對b作微分的結果
b_gradient = (2*(w*x+b -y)) .mean()
w_gradient
# Out:
# 634.7315151515153

# %%
def compute_gradient(x ,y ,w ,b):
   w_gradient = (x*(w*x+b -y)).mean()
   b_gradient = ((w*x+b -y)) .mean()
   return w_gradient ,b_gradient

# %%
compute_gradient(x ,y ,20 ,10)
# Out:
# (268.54757575757577, 35.084848484848486)

# %%
def compute_cost(x, y ,w ,b):
   y_pred = w*x +b
   cost = (y-y_pred)**2 #cost 為(真實值-預測值)**2
   cost = cost.sum() / len(x)

   return cost

# %%
w = 0
b = 0
learning_rate = 0.001
def gradient_descent(x ,y ,w_init ,b_init ,learning_rate ,cost_function ,gradient_function ,run_iter ,p_iter=1000):
  w = w_init
  b = b_init

  c_hist = []
  w_hist = []
  b_hist = []

  for i in range(run_iter):
   w_gradient ,b_gradient = gradient_function(x ,y ,w ,b)

   w = w - w_gradient*learning_rate #持續更新W值
   b = b - b_gradient*learning_rate #持續更新b值
   cost = cost_function(x, y ,w ,b)

   w_hist.append(w)
   b_hist.append(b)
   c_hist.append(cost)

   if i%p_iter == 0:
     print(f"Ieration {i:5} : Cost {cost: .4e} ,w: {w: .4e} ,b: {b: .4e} ,w_gradient: {w_gradient: .4e} ,b_gradient: {b_gradient: .4e}") #{i:3}-排列有3個空位 {a:.5f}-小數點後面有5個數字
  return w ,b ,w_hist ,b_hist ,c_hist

# %%
w_init = 0
b_init = 0
learning_rate = 1.0e-3
run_iter = 20000

w_final ,b_final ,w_hist ,b_hist ,c_hist = gradient_descent(x ,y ,w_init ,b_init ,learning_rate ,compute_cost ,compute_gradient ,run_iter)
# Out:
# Ieration     0 : Cost  5.6568e+03 ,w:  4.3578e-01 ,b:  7.2552e-02 ,w_gradient: -4.3578e+02 ,b_gradient: -7.2552e+01
# Ieration  1000 : Cost  1.4097e+02 ,w:  1.2119e+01 ,b:  8.0666e+00 ,w_gradient:  7.9958e-01 ,b_gradient: -5.3245e+00
# Ieration  2000 : Cost  9.6063e+01 ,w:  1.1417e+01 ,b:  1.2739e+01 ,w_gradient:  6.1226e-01 ,b_gradient: -4.0771e+00
# Ieration  3000 : Cost  6.9732e+01 ,w:  1.0880e+01 ,b:  1.6317e+01 ,w_gradient:  4.6882e-01 ,b_gradient: -3.1220e+00
# Ieration  4000 : Cost  5.4293e+01 ,w:  1.0468e+01 ,b:  1.9057e+01 ,w_gradient:  3.5899e-01 ,b_gradient: -2.3906e+00
# Ieration  5000 : Cost  4.5241e+01 ,w:  1.0153e+01 ,b:  2.1154e+01 ,w_gradient:  2.7489e-01 ,b_gradient: -1.8305e+00
# Ieration  6000 : Cost  3.9933e+01 ,w:  9.9122e+00 ,b:  2.2761e+01 ,w_gradient:  2.1049e-01 ,b_gradient: -1.4017e+00
# Ieration  7000 : Cost  3.6821e+01 ,w:  9.7275e+00 ,b:  2.3991e+01 ,w_gradient:  1.6118e-01 ,b_gradient: -1.0733e+00
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(0 ,60) ,c_hist[ :60]) #x值用np.arange y值用cost 把cost畫成圖來看
plt.title("iteration vs cost")
plt.xlabel("iteration")
plt.ylabel("cost")

plt.show()

# %%
print(f"最終w b=({w_final:.2f} ,{b_final:.2f})")
# Out:
# 最終w b=(9.14 ,27.89)

# %%
print(f"年資2   預測薪水{w_final*2 + b_final:.1f}K")
print(f"年資5.9  預測薪水{w_final*5.9 + b_final:.1f}K")
# Out:
# 年資2   預測薪水46.2K
# 年資5.9  預測薪水81.8K

# %%
ws = np.arange(-100 ,101)
bs = np.arange(-100 ,101)
costs = np.zeros([201 ,201])
i = 0
for w in ws:
  j = 0
  for b in bs:
    cost = compute_cost(x, y ,w ,b)
    costs[i,j] = cost
    j = j+1
  i = i+1

# %%
# !wget -O taipei_sans_tc_beta.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
# Out:
# --2024-10-20 13:34:49--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 209.85.200.100, 209.85.200.101, 209.85.200.102, ...
# Connecting to drive.google.com (drive.google.com)|209.85.200.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-10-20 13:34:49--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 108.177.121.132, 2607:f8b0:4001:c19::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|108.177.121.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘taipei_sans_tc_beta.ttf’
#
# taipei_sans_tc_beta 100%[===================>]  19.70M   102MB/s    in 0.2s
# ...

# %%
w_init = -200
b_init = -200
learning_rate = 2.0e-2
run_iter = 1000

w_final ,b_final ,w_hist ,b_hist ,c_hist = gradient_descent(x ,y ,w_init ,b_init ,learning_rate ,compute_cost ,compute_gradient ,run_iter)
# Out:
# Ieration     0 : Cost  2.2115e+05 ,w: -4.0655e+01 ,b: -1.7502e+02 ,w_gradient: -7.9672e+03 ,b_gradient: -1.2489e+03

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager
mpl.font_manager.fontManager.addfont('taipei_sans_tc_beta.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')

plt.figure(figsize=(7 ,7)) #調整畫出的圖的大小

ax = plt.axes(projection="3d")
ax.view_init(30 ,-80) #上下選轉角度 左右旋轉角度
ax.xaxis.set_pane_color((0,0,0))
ax.yaxis.set_pane_color((0,0,0))
ax.zaxis.set_pane_color((0,0,0))
b_grid ,w_grid = np.meshgrid(bs ,ws)
ax.plot_surface(w_grid ,b_grid ,costs ,alpha = 0.3) #alpha使圖面變為透明

ax.set_title("w b 對應的 cost")
ax.set_xlabel("w")
ax.set_ylabel("b")
ax.set_zlabel("cost")

w_index ,b_index = np.where(costs == np.min(costs)) #找出最低的cost
ax.scatter(ws[w_index] ,bs[b_index] ,costs[w_index ,b_index] ,color="red" ,s=40) #畫出最小cost的點(修改顏色和大小)
ax.scatter(w_hist[0] ,b_hist[0] ,c_hist[0] ,color="green" ,s=40)
ax.plot(w_hist ,b_hist ,c_hist)

plt.show()
print(f"當w={ws[w_index]} ,b={bs[b_index]} 會有最小cost:{costs[w_index ,b_index]}") #找出最低cost的w和b的值
# Out:
# 當w=[9] ,b=[29] 會有最小cost:[32.69484848]
